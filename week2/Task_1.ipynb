# %%
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('/home/aszummer/Documents/MCV/M6/mcv-m6-2022-team3/std.png',0)

# %%
img.shape
# Out:
# (1080, 1920)

# %%
plt.imshow(img)

# %%
mean_data_exist = cv2.imread('mean.png',0)

# %%
mean_data_exist.shape
# Out:
# (1080, 1920)

# %%
if mean_data_exist is not None:
    print(200)
else:
    print(300)
# Out:
# 200
